# %% [markdown]
# # 4. Datahåndtering
#
# ```{admonition} Læringsutbytte
# Etter å ha arbeidet med dette temaet, skal du kunne:
# 1. Lese data fra fil.
# 2. Plotte fildata.
# 3. Utføre regresjon for å modellere sammenhenger i fildata.
# 4. Bruke enkel statistikk (gjennomsnitt, standardavvik).
# ```
#
# ## Lese fra fil
# I videoen nedenfor forklares hvordan du kan lese datafiler med Python.

# %%
from IPython.display import HTML
# Youtube
HTML('<iframe width="800" height="600" src="https://www.youtube.com/embed/EqE0RU82gIU? autoplay=0&rel=0" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="800" height="600" src="https://www.youtube.com/embed/EqE0RU82gIU? autoplay=0&rel=0" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Når du har sett videoen, kan du gjøre følgende oppgave for å sjekke om du forstår innholdet:
#
# ```{admonition} Underveisoppgave
# :class: tip
# Fila *temperatur.txt* inneholder temperaturmålinger som funksjon av tid. Les av fila og plott fildataene.
# ```
#
# <iframe src="https://trinket.io/embed/python3/8ad50748d8" width="100%" height="356" frameborder="0" marginwidth="0" marginheight="0" allowfullscreen></iframe>
#
# ## Regresjon
# Her skal vi se hvordan vi kan utføre regresjon på datapunkter.

# %%
from IPython.display import HTML
# Youtube
HTML('<iframe width="800" height="600" src="https://www.youtube.com/embed/l7aAcyzA4VE? autoplay=0&rel=0" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="800" height="600" src="https://www.youtube.com/embed/l7aAcyzA4VE? autoplay=0&rel=0" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Når du har sett videoen, kan du gjøre følgende oppgave for å sjekke om du forstår innholdet:
#
# ```{admonition} Underveisoppgave
# :class: tip
# Benytt koderuta i forrige underveisoppgave og utfør regresjon av 1. og 2. grad av datapunktene ovenfor. Plott regresjonskurvene i samme koordinatsystem som datapunktene.
# ```
