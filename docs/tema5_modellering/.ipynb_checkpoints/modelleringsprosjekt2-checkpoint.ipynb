# %% [markdown]
# # Modelleringsoppgave II

# %% [markdown]
# I dette prosjektet skal dere modellere en naturvitenskapelig sammenheng ved å bruke differensiallikninger. Prosjektet skal presenteres på en ryddig måte med teori, programkode og drøfting i Jupyter Notebook. Dere vil bli vurdert etter følgende kriterier:
#
# - Koden virker og er lagt opp på en god måte.
# - Koden er strukturert og oversiktlig.
# - Det kommer fram at dere kjenner godt til grunnleggende programmering.
# - Det kommer fram at dere forstår det realfaglige innholdet.
# - Rapporten er ryddig og oversiktlig. Rapporten skal ikke være inndelt etter _oppgaver_, men ha en klar struktur:
#     1. Introduksjon: Hva dreier prosjektet seg om. Hva skal du vise/gjøre?
#     2. Hvilke metoder bruker du? Utled metodene.
#         \item Beskrivelse og resultater: Gjør rede for framgangsmåte og programmer. IKKE \textit{drøft} resultatene!
#         \item Drøfting: Drøft de ulike modellene. Begrensninger, forutsetninger, antakelser, konsekvenser. Hva betyr endring av de ulike parametrene?
#         \item Konklusjon: Hva har du gjort, og hvordan? Kort oppsummering.
#     \end{enumerate}
#     \item Alle figurer og grafer er oversiktlige med figurtekst, aksetitler o.l.
#     \item Alle resultater er drøfta og redegjort for.
# \end{enumerate}
#
# \section{Oppgaver}
# Velg én av oppgavene nedenfor, eller foreslå en problemstilling for læreren. Problemstillingen må bli godkjent før dere går igang med prosjektet. \\
# \newpage
#
# \noindent {\Large \textbf{Oppgave 1: Zombie-apokalypse}}
#
# \noindent Denne oppgava tar utgangspunkt i å modellere og simulere en menneskepopulasjon under en zombie-apokalypse. Gjør rede for begrensninger for modellene dine, og drøft hva de forteller oss om populasjonen.
#
# \vspace{3mm}
#
# \begin{wrapfigure}{R}{0.3\textwidth}
# \includegraphics[height=10cm, width=0.5\textwidth]{Alexandria.jpg}
# \end{wrapfigure}
#
# \noindent \textit{Utgangspunkt}
#
# \noindent Vi befinner oss i en postapokalyptisk situasjon der verden har blitt utsatt for et virus som gjør mennesker om til zombier. Viruset smitter kun via blod, f.eks. ved bitt eller kloring fra zombier. Vi skal studere en avsideliggende landsby, Alexandria, som ligger i nærheten av Washington D.C., og som etter et zombie-utbrudd har blitt et tilfluktssted for 500 mennesker. De har tilgang til en del mat og våpen, og de har en mur rundt hele landsbyen som holder zombiene unna. Men de må også ut for å finne nye ressurser og andre mennesker som trenger hjelp, så de er aldri helt trygge.
#
# \vspace{3mm}
# \noindent \textit{Oppgave}
#
# \noindent Modellen din kan inneholde mange ulike faktorer, og du står fritt til å legge til flere, dersom du begrunner det. Legg til én og én faktor, og test modellen etter hver gang. Kommenter populasjonsutviklinga etter hver nye faktor er lagt til.
#
# \begin{enumerate}
# \item Lag først et program der menneskene er trygge mot zombier, og der nye mennesker kan komme til ved fødsel og (mer sannsynlig) innvandring. Lag gjerne ett ledd i likninga som inkluderer begge disse faktorene.
# \end{enumerate}
#
# \begin{enumerate}
# \setcounter{enumi}{1}
# \item Legg inn en ressursbegrensning (bæreevne) for populasjonen. Hvilke faktorer påvirker denne?
#
# \item Menneskene kan også dø av sykdom, skade og alderdom (naturlig død). Legg dette inn i modellen, og tenk på hvor sannsynlig dette er (hvor god er tilgangen på medisiner, lege o.l.?).
#
# \item Nå skal du legge inn en zombiepopulasjon som lever i nærheten av Alexandria. Du kan selv bestemme hvor mange zombier som finnes og hvor sannsynlig det er at mennesker blir drept av en zombie. Zombiene fungerer som rovdyr, slik at menneskene ikke blir til zombier i denne modellen.
#
# \item Nå kan du legge inn muligheten for at mennesker blir til zombier hvis de blir bitt, men ikke revet i fillebiter. Det vil si at noen mennesker vil bli smitta, mens andre vil bli drept av zombiene. De som blir smitta, blir til zombier, og dermed øker zombiepopulasjonen.
#
# \item Alexandria kan slå tilbake mot zombiene. Legg inn en faktor som bidrar til at menneskene kan ta livet av zombier.
#
# \item I nærheten av Alexandria finner vi landsbyene Hilltop og Kingdom. Fra disse kan det komme forsterkninger til Alexandria ved behov. Inkluder dette i modellen din.
# \end{enumerate}
#
# \vspace{5mm}
#
#
# \noindent {\Large \textbf{Oppgave 2: Epidemiologi}} \\
# I disse tider er vi nært berørt av pandemien som er forårsaka av Covid-19-viruset. Her skal vi studere en såkalt SIR-epidemimodell der den totale populasjonsstørrelsen N er delt inn i tre epidemiologiske klasser: utsatte (susceptible = S), infiserte (infected = I) og de som har blitt friske og dermed immune (recovered = R).
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[scale=0.4]{koronavirus.jpg}
#     \caption{Koronaviruset}
#     \label{fig:my_label}
# \end{figure}
#
# \begin{enumerate}
#     \item Gjør først oppgave 8.21 i boka.
#     \item Finn data på antall smittede i Norge på internett (f.eks. FHI). Legg dataene i en fil, les dataene og plott antall smittede som funksjon av tid. Du kan begrense dataene slik at du f.eks. ser på tidsrommet mars-juni 2020.
#     \item Gjør en regresjonsanalyse med \textit{polyfit} og tilpass en modell til tallene.
#     \item FHI (Folkehelseinstituttet) regna i mars 2020 med at opptil 2,2 millioner nordmenn kan bli smittet. Når skulle dette skjedd følge modellen din?
#     \item Tilpass SIR-modellen din fra oppgave a) til koronasituasjonen i Norge eller USA. Kommenter hvilke tilpasninger du har gjort og begrunn valgene dine.
#     \item Lag plott og drøft utfallene av simuleringene du gjør med SIR-modellen i forrige oppgave.
# \end{enumerate}
# Finn så data på nettet (FHI er en god kilde) om koronaviruset i Norge. Tilpass modellen til disse dataene. \\
#
# \newpage
#
# \noindent {\Large \textbf{Oppgave 3: Solsystemet}}
#
# \noindent I denne oppgava skal du bruke Newtons gravitasjonslov til å simulere solsystemet. Oppgava er beskrevet i boka (oppgave 8.22).
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[scale=0.2]{solsystem.jpg}
#     \caption{Solsystemet slik det nesten er...}
#     \label{fig:my_label}
# \end{figure}
#
# \noindent {\Large \textbf{Oppgave 4: Newtons lover}} \\
# Her skal du utforske friksjon og luftmotstand nærmere. Gjør oppgave 8.20 og 8.23 i boka. Ikke svar på hver deloppgave hver for seg, men lag en enhetlig rapport.
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[scale=0.5]{friksjon.jpg}
#     \caption{Friksjon kan være utfordrende.}
#     \label{fig:my_label}
# \end{figure}
#
# \end{document}
